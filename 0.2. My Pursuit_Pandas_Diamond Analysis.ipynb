# %%
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

# %%
diamonds.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # Query only some columns

# %%
user_cols = ['carat','cut','x','y','z']
diamonds[user_cols].head(6)
# Out:
#    carat        cut     x     y     z
# 0   0.23      Ideal  3.95  3.98  2.43
# 1   0.21    Premium  3.89  3.84  2.31
# 2   0.23       Good  4.05  4.07  2.31
# 3   0.29    Premium  4.20  4.23  2.63
# 4   0.31       Good  4.34  4.35  2.75
# 5   0.24  Very Good  3.94  3.96  2.48

# %% [markdown]
# # select a series from diamonds DataFrame

# %%
diamonds['cut']
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# # Adding New Column

# %%
diamonds['Quality_color'] = diamonds.cut + ',' + diamonds.color

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality_color
# 0       Ideal,E
# 1     Premium,E
# 2        Good,E
# 3     Premium,I
# 4        Good,J

# %% [markdown]
# ## Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

# %%
diamonds.shape
# Out:
# (53940, 11)

# %%
diamonds.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality_color     object
# dtype: object

# %% [markdown]
# # 6. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
diamonds.describe(include=['object'])
# Out:
#           cut  color clarity Quality_color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1       Ideal,G
# freq    21551  11292   13065          4884

# %% [markdown]
# # Write a Pandas program to rename two of the columns of the diamonds Dataframe.

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality_color
# 0       Ideal,E
# 1     Premium,E
# 2        Good,E
# 3     Premium,I
# 4        Good,J

# %%
diamonds.rename(columns={'cut':'Cut', 'color':'Color'}, inplace = True)

# %%
diamonds.head()
# Out:
#    carat      Cut Color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality_color
# 0       Ideal,E
# 1     Premium,E
# 2        Good,E
# 3     Premium,I
# 4        Good,J

# %% [markdown]
# # 8. Write a Pandas program to rename all the columns of the diamonds Dataframe.

# %%
diamonds_cols = ['New Carat','New Cut','New Color','New Clarity','New Depth','New Table','New Price','New x','New y','New z','Quality Color']

# %%
diamonds.columns = diamonds_cols

# %%
diamonds.head()
# Out:
#    New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 0       0.23    Ideal         E         SI2       61.5       55.0        326
# 1       0.21  Premium         E         SI1       59.8       61.0        326
# 2       0.23     Good         E         VS1       56.9       65.0        327
# 3       0.29  Premium         I         VS2       62.4       58.0        334
# 4       0.31     Good         J         SI2       63.3       58.0        335
#
#    New x  New y  New z Quality Color
# 0   3.95   3.98   2.43       Ideal,E
# 1   3.89   3.84   2.31     Premium,E
# 2   4.05   4.07   2.31        Good,E
# 3   4.20   4.23   2.63     Premium,I
# 4   4.34   4.35   2.75        Good,J

# %% [markdown]
# # 9. Write a Pandas program to remove the second column of the diamonds Dataframe.

# %%
diamonds.head()
# Out:
#    New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 0       0.23    Ideal         E         SI2       61.5       55.0        326
# 1       0.21  Premium         E         SI1       59.8       61.0        326
# 2       0.23     Good         E         VS1       56.9       65.0        327
# 3       0.29  Premium         I         VS2       62.4       58.0        334
# 4       0.31     Good         J         SI2       63.3       58.0        335
#
#    New x  New y  New z Quality Color
# 0   3.95   3.98   2.43       Ideal,E
# 1   3.89   3.84   2.31     Premium,E
# 2   4.05   4.07   2.31        Good,E
# 3   4.20   4.23   2.63     Premium,I
# 4   4.34   4.35   2.75        Good,J

# %%
diamonds.drop('New Cut', axis = 1)
#If you able to add "inplace = True" @ the end of the command, then dataframe will saved.
# Out:
#        New Carat New Color New Clarity  New Depth  New Table  New Price  \
# 0           0.23         E         SI2       61.5       55.0        326
# 1           0.21         E         SI1       59.8       61.0        326
# 2           0.23         E         VS1       56.9       65.0        327
# 3           0.29         I         VS2       62.4       58.0        334
# 4           0.31         J         SI2       63.3       58.0        335
# ...          ...       ...         ...        ...        ...        ...
# 53935       0.72         D         SI1       60.8       57.0       2757
# 53936       0.72         D         SI1       63.1       55.0       2757
# 53937       0.70         D         SI1       62.8       60.0       2757
# 53938       0.86         H         SI2       61.0       58.0       2757
# 53939       0.75         D         SI2       62.2       55.0       2757
#
#        New x  New y  New z Quality Color
# 0       3.95   3.98   2.43       Ideal,E
# ...

# %%
diamonds.head()
# Out:
#    New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 0       0.23    Ideal         E         SI2       61.5       55.0        326
# 1       0.21  Premium         E         SI1       59.8       61.0        326
# 2       0.23     Good         E         VS1       56.9       65.0        327
# 3       0.29  Premium         I         VS2       62.4       58.0        334
# 4       0.31     Good         J         SI2       63.3       58.0        335
#
#    New x  New y  New z Quality Color
# 0   3.95   3.98   2.43       Ideal,E
# 1   3.89   3.84   2.31     Premium,E
# 2   4.05   4.07   2.31        Good,E
# 3   4.20   4.23   2.63     Premium,I
# 4   4.34   4.35   2.75        Good,J

# %% [markdown]
# ## 10. Write a Pandas program to remove multiple columns at once of the diamonds Dataframe.

# %%
drop_cols = ['New Cut','New Table','New Price']
diamonds.drop(drop_cols, axis = 1)
# Out:
#        New Carat New Color New Clarity  New Depth  New x  New y  New z  \
# 0           0.23         E         SI2       61.5   3.95   3.98   2.43
# 1           0.21         E         SI1       59.8   3.89   3.84   2.31
# 2           0.23         E         VS1       56.9   4.05   4.07   2.31
# 3           0.29         I         VS2       62.4   4.20   4.23   2.63
# 4           0.31         J         SI2       63.3   4.34   4.35   2.75
# ...          ...       ...         ...        ...    ...    ...    ...
# 53935       0.72         D         SI1       60.8   5.75   5.76   3.50
# 53936       0.72         D         SI1       63.1   5.69   5.75   3.61
# 53937       0.70         D         SI1       62.8   5.66   5.68   3.56
# 53938       0.86         H         SI2       61.0   6.15   6.12   3.74
# 53939       0.75         D         SI2       62.2   5.83   5.87   3.64
#
#       Quality Color
# 0           Ideal,E
# 1         Premium,E
# 2            Good,E
# 3         Premium,I
# ...

# %% [markdown]
# ## 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe

# %%
diamonds.drop([2,3,4,5], axis = 0)
# Out:
#        New Carat    New Cut New Color New Clarity  New Depth  New Table  \
# 0           0.23      Ideal         E         SI2       61.5       55.0
# 1           0.21    Premium         E         SI1       59.8       61.0
# 6           0.24  Very Good         I        VVS1       62.3       57.0
# 7           0.26  Very Good         H         SI1       61.9       55.0
# 8           0.22       Fair         E         VS2       65.1       61.0
# ...          ...        ...       ...         ...        ...        ...
# 53935       0.72      Ideal         D         SI1       60.8       57.0
# 53936       0.72       Good         D         SI1       63.1       55.0
# 53937       0.70  Very Good         D         SI1       62.8       60.0
# 53938       0.86    Premium         H         SI2       61.0       58.0
# 53939       0.75      Ideal         D         SI2       62.2       55.0
#
#        New Price  New x  New y  New z Quality Color
# ...

# %% [markdown]
# ## 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
diamonds.sort_values('New Cut', ascending = True)
# Out:
#        New Carat    New Cut New Color New Clarity  New Depth  New Table  \
# 3850        1.01       Fair         F         SI2       64.8       55.0
# 51464       1.20       Fair         G          I1       66.6       57.0
# 51466       0.90       Fair         G         SI2       65.4       57.0
# 10237       1.26       Fair         D         SI2       64.5       59.0
# 10760       1.01       Fair         E         SI1       69.5       55.0
# ...          ...        ...       ...         ...        ...        ...
# 7402        0.33  Very Good         G         VS2       62.8       54.0
# 43101       0.57  Very Good         E         SI2       58.8       57.3
# 16893       1.00  Very Good         G         VS2       62.2       58.0
# 16898       1.00  Very Good         D         VS2       59.6       60.0
# 21164       1.00  Very Good         E        VVS2       61.7       55.0
#
#        New Price  New x  New y  New z Quality Color
# ...

# %% [markdown]
# ## 13. Write a Pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe.

# %%
result_price_descending = diamonds.sort_values('New Price', ascending = False).head()

# %%
result_price_descending
# Out:
#        New Carat    New Cut New Color New Clarity  New Depth  New Table  \
# 27749       2.29    Premium         I         VS2       60.8       60.0
# 27748       2.00  Very Good         G         SI1       63.5       56.0
# 27747       1.51      Ideal         G          IF       61.7       55.0
# 27746       2.07      Ideal         G         SI2       62.5       55.0
# 27745       2.00  Very Good         H         SI1       62.8       57.0
#
#        New Price  New x  New y  New z Quality Color
# 27749      18823   8.50   8.47   5.16     Premium,I
# 27748      18818   7.90   7.97   5.04   Very Good,G
# 27747      18806   7.37   7.41   4.56       Ideal,G
# 27746      18804   8.20   8.13   5.11       Ideal,G
# 27745      18803   7.95   8.00   5.01   Very Good,H

# %% [markdown]
# ## 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
result_price_ascending = diamonds.sort_values('New Price', ascending = True)

# %%
result_price_descending = diamonds.sort_values('New Price', ascending = False)

# %%
result_price_ascending.head()
# Out:
#    New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 0       0.23    Ideal         E         SI2       61.5       55.0        326
# 1       0.21  Premium         E         SI1       59.8       61.0        326
# 2       0.23     Good         E         VS1       56.9       65.0        327
# 3       0.29  Premium         I         VS2       62.4       58.0        334
# 4       0.31     Good         J         SI2       63.3       58.0        335
#
#    New x  New y  New z Quality Color
# 0   3.95   3.98   2.43       Ideal,E
# 1   3.89   3.84   2.31     Premium,E
# 2   4.05   4.07   2.31        Good,E
# 3   4.20   4.23   2.63     Premium,I
# 4   4.34   4.35   2.75        Good,J

# %%
result_price_descending.head()
# Out:
#        New Carat    New Cut New Color New Clarity  New Depth  New Table  \
# 27749       2.29    Premium         I         VS2       60.8       60.0
# 27748       2.00  Very Good         G         SI1       63.5       56.0
# 27747       1.51      Ideal         G          IF       61.7       55.0
# 27746       2.07      Ideal         G         SI2       62.5       55.0
# 27745       2.00  Very Good         H         SI1       62.8       57.0
#
#        New Price  New x  New y  New z Quality Color
# 27749      18823   8.50   8.47   5.16     Premium,I
# 27748      18818   7.90   7.97   5.04   Very Good,G
# 27747      18806   7.37   7.41   4.56       Ideal,G
# 27746      18804   8.20   8.13   5.11       Ideal,G
# 27745      18803   7.95   8.00   5.01   Very Good,H

# %% [markdown]
# ## 15. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
diamonds.loc[diamonds['New Carat'] >= 0.3]
# Out:
#        New Carat    New Cut New Color New Clarity  New Depth  New Table  \
# 4           0.31       Good         J         SI2       63.3       58.0
# 10          0.30       Good         J         SI1       64.0       55.0
# 13          0.31      Ideal         J         SI2       62.2       54.0
# 15          0.32    Premium         E          I1       60.9       58.0
# 16          0.30      Ideal         I         SI2       62.0       54.0
# ...          ...        ...       ...         ...        ...        ...
# 53935       0.72      Ideal         D         SI1       60.8       57.0
# 53936       0.72       Good         D         SI1       63.1       55.0
# 53937       0.70  Very Good         D         SI1       62.8       60.0
# 53938       0.86    Premium         H         SI2       61.0       58.0
# 53939       0.75      Ideal         D         SI2       62.2       55.0
#
#        New Price  New x  New y  New z Quality Color
# ...

# %% [markdown]
# ## 16. Write a Pandas program to convert a python list to pandas series.

# %%
list1 = [1,2,3,4]
df1 = pd.Series(list1)
df1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ## 17. Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
diamonds.head()
# Out:
#    New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 0       0.23    Ideal         E         SI2       61.5       55.0        326
# 1       0.21  Premium         E         SI1       59.8       61.0        326
# 2       0.23     Good         E         VS1       56.9       65.0        327
# 3       0.29  Premium         I         VS2       62.4       58.0        334
# 4       0.31     Good         J         SI2       63.3       58.0        335
#
#    New x  New y  New z Quality Color
# 0   3.95   3.98   2.43       Ideal,E
# 1   3.89   3.84   2.31     Premium,E
# 2   4.05   4.07   2.31        Good,E
# 3   4.20   4.23   2.63     Premium,I
# 4   4.34   4.35   2.75        Good,J

# %%
diamonds[['New x', 'New y', 'New z']] = diamonds[['New x', 'New y', 'New z']].apply(pd.to_numeric)

# %%
diamonds[(diamonds['New x'] >= 5) & (diamonds['New y'] >= 5) & (diamonds['New z'] >= 5)]
# Out:
#        New Carat    New Cut New Color New Clarity  New Depth  New Table  \
# 11778       1.83       Fair         J          I1       70.0       58.0
# 13002       2.14       Fair         J          I1       69.4       57.0
# 13118       2.15       Fair         J          I1       65.5       57.0
# 13562       1.96       Fair         F          I1       66.6       60.0
# 13757       2.22       Fair         J          I1       66.7       56.0
# ...          ...        ...       ...         ...        ...        ...
# 27748       2.00  Very Good         G         SI1       63.5       56.0
# 27749       2.29    Premium         I         VS2       60.8       60.0
# 48410       0.51  Very Good         E         VS1       61.8       54.7
# 49189       0.51      Ideal         E         VS1       61.8       55.0
# 49905       0.50  Very Good         G        VVS1       63.7       58.0
#
#        New Price  New x  New y  New z Quality Color
# ...

# %% [markdown]
# ## 18. Write a Pandas program to find the diamonds that are either Premium or Ideal.

# %%
diamonds.loc[(diamonds['New Cut'] == 'Premium') | (diamonds['New Cut'] == 'Ideal')]. head(20)
# Out:
#     New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 0        0.23    Ideal         E         SI2       61.5       55.0        326
# 1        0.21  Premium         E         SI1       59.8       61.0        326
# 3        0.29  Premium         I         VS2       62.4       58.0        334
# 11       0.23    Ideal         J         VS1       62.8       56.0        340
# 12       0.22  Premium         F         SI1       60.4       61.0        342
# 13       0.31    Ideal         J         SI2       62.2       54.0        344
# 14       0.20  Premium         E         SI2       60.2       62.0        345
# 15       0.32  Premium         E          I1       60.9       58.0        345
# 16       0.30    Ideal         I         SI2       62.0       54.0        348
# 26       0.24  Premium         I         VS1       62.5       57.0        355
# 39       0.33    Ideal         I         SI2       61.8       55.0        403
# ...

# %% [markdown]
# ## 19. Write a Pandas program to find the diamonds that are with a Fair or Good or Premium.

# %%
diamonds.loc[(diamonds['New Cut'] == 'Fair') | (diamonds['New Cut'] == 'Good') | (diamonds['New Cut'] == 'Premium')].head(20)
# Out:
#     New Carat  New Cut New Color New Clarity  New Depth  New Table  New Price  \
# 1        0.21  Premium         E         SI1       59.8       61.0        326
# 2        0.23     Good         E         VS1       56.9       65.0        327
# 3        0.29  Premium         I         VS2       62.4       58.0        334
# 4        0.31     Good         J         SI2       63.3       58.0        335
# 8        0.22     Fair         E         VS2       65.1       61.0        337
# 10       0.30     Good         J         SI1       64.0       55.0        339
# 12       0.22  Premium         F         SI1       60.4       61.0        342
# 14       0.20  Premium         E         SI2       60.2       62.0        345
# 15       0.32  Premium         E          I1       60.9       58.0        345
# 17       0.30     Good         J         SI1       63.4       54.0        351
# 18       0.30     Good         J         SI1       63.8       56.0        351
# ...

# %% [markdown]
# ## 20. Write a Pandas program to display all column labels of diamonds DataFrame.

# %%
diamonds.columns
# Out:
# Index(['New Carat', 'New Cut', 'New Color', 'New Clarity', 'New Depth',
#        'New Table', 'New Price', 'New x', 'New y', 'New z', 'Quality Color'],
#       dtype='object')

# %% [markdown]
# ## 21. Write a Pandas program to read only a subset of 3 rows from diamonds DataFrame.

# %%
result_3_rows = pd.read_csv('http://bit.ly/uforeports',nrows = 3)

# %%
result_3_rows
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# ## 22. Write a Pandas program to iterate through diamonds DataFrame.

# %%
diamonds.columns
# Out:
# Index(['New Carat', 'New Cut', 'New Color', 'New Clarity', 'New Depth',
#        'New Table', 'New Price', 'New x', 'New y', 'New z', 'Quality Color'],
#       dtype='object')

# %%
new_cols = ['Carat','Cut','Color','Clarity','Depth','Table','Price','x','y','z','Quality_Color']

diamonds.columns = new_cols

diamonds.head()
# Out:
#    Carat      Cut Color Clarity  Depth  Table  Price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality_Color
# 0       Ideal,E
# 1     Premium,E
# 2        Good,E
# 3     Premium,I
# 4        Good,J

# %%
for index,row in diamonds.iterrows():
    print(index, row.Carat, row.Cut)
# Out:
# 0 0.23 Ideal
# 1 0.21 Premium
# 2 0.23 Good
# 3 0.29 Premium
# 4 0.31 Good
# 5 0.24 Very Good
# 6 0.24 Very Good
# 7 0.26 Very Good
# 8 0.22 Fair
# 9 0.23 Very Good
# 10 0.3 Good
# 11 0.23 Ideal
# 12 0.22 Premium
# 13 0.31 Ideal
# 14 0.2 Premium
# 15 0.32 Premium
# 16 0.3 Ideal
# 17 0.3 Good
# 18 0.3 Good
# 19 0.3 Very Good
# 20 0.3 Good
# 21 0.23 Very Good
# 22 0.23 Very Good
# 23 0.31 Very Good
# 24 0.31 Very Good
# 25 0.23 Very Good
# 26 0.24 Premium
# 27 0.3 Very Good
# 28 0.23 Very Good
# 29 0.23 Very Good
# 30 0.23 Very Good
# 31 0.23 Very Good
# 32 0.23 Very Good
# 33 0.23 Very Good
# 34 0.23 Very Good
# 35 0.23 Good
# 36 0.23 Good
# 37 0.31 Good
# 38 0.26 Very Good
# 39 0.33 Ideal
# 40 0.33 Ideal
# 41 0.33 Ideal
# 42 0.26 Good
# 43 0.26 Good
# 44 0.32 Good
# 45 0.29 Premium
# 46 0.32 Very Good
# 47 0.32 Good
# 48 0.25 Very Good
# 49 0.29 Very Good
# 50 0.24 Very Good
# 51 0.23 Ideal
# 52 0.32 Ideal
# 53 0.22 Premium
# 54 0.22 Premium
# 55 0.3 Ideal
# 56 0.3 Premium
# ...
