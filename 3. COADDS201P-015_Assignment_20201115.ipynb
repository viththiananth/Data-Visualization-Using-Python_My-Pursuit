# %% [markdown]
# ## COADDS201P-015
# ## T.Viththiananth

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# ## Q1 : Load the three datasets given in csv formats as pandas Data frames

# %%
FV_df = pd.read_csv('FV.csv')
Sales_df = pd.read_csv('sales DF.csv')
Stores_df = pd.read_csv('stores DF.csv')

# %%
FV_df.head(5)
# Out:
#    Store        Date  Temperature  Fuel_Price  Stock Price  Unemployment  \
# 0      1    5/2/2010        42.31       2.572   211.096358         8.106
# 1      1   12/2/2010        38.51       2.548   211.242170         8.106
# 2      1  19/02/2010        39.93       2.514   211.289143         8.106
# 3      1  26/02/2010        46.63       2.561   211.319643         8.106
# 4      1    5/3/2010        46.50       2.625   211.350143         8.106
#
#    HolidayIndicator
# 0             False
# 1              True
# 2             False
# 3             False
# 4             False

# %%
Sales_df.head(5)
# Out:
#    Store  Dept        Date  WeeklySales  HolidayIndicator
# 0      1     1    5/2/2010     24924.50             False
# 1      1     1   12/2/2010     46039.49              True
# 2      1     1  19/02/2010     41595.55             False
# 3      1     1  26/02/2010     19403.54             False
# 4      1     1    5/3/2010     21827.90             False

# %%
Stores_df.head(5)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %% [markdown]
# ## Q2 : Replace the missing values if any exists in the three data sets according to the below instructions

# %%
FV_df.isna().sum()
# Out:
# Store                 0
# Date                  0
# Temperature           0
# Fuel_Price            0
# Stock Price         585
# Unemployment        585
# HolidayIndicator      0
# dtype: int64

# %%
Stores_df.isna().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
Sales_df.isna().sum()
# Out:
# Store               0
# Dept                0
# Date                0
# WeeklySales         0
# HolidayIndicator    0
# dtype: int64

# %%
FV_df['Stock Price'].fillna(FV_df['Stock Price'].mean(), inplace = True)

# %%
FV_df.isna().sum()
# Out:
# Store                 0
# Date                  0
# Temperature           0
# Fuel_Price            0
# Stock Price           0
# Unemployment        585
# HolidayIndicator      0
# dtype: int64

# %%
FV_df['Unemployment'].fillna(FV_df['Unemployment'].mean(), inplace=True)

# %%
FV_df.isna().sum()
# Out:
# Store               0
# Date                0
# Temperature         0
# Fuel_Price          0
# Stock Price         0
# Unemployment        0
# HolidayIndicator    0
# dtype: int64

# %% [markdown]
# ## Q2 : Derive two new columns as month and year from the date column in the sales DF sheet.

# %%
Sales_df.head(5)
# Out:
#    Store  Dept        Date  WeeklySales  HolidayIndicator
# 0      1     1    5/2/2010     24924.50             False
# 1      1     1   12/2/2010     46039.49              True
# 2      1     1  19/02/2010     41595.55             False
# 3      1     1  26/02/2010     19403.54             False
# 4      1     1    5/3/2010     21827.90             False

# %%
Sales_df.dtypes
# Out:
# Store                 int64
# Dept                  int64
# Date                 object
# WeeklySales         float64
# HolidayIndicator       bool
# year                  int64
# Month                 int64
# dtype: object

# %%
Sales_df['year'] = pd.DatetimeIndex(Sales_df['Date']).year

# %%
Sales_df['Month'] = pd.DatetimeIndex(Sales_df['Date']).month

# %%
Sales_df.head()
# Out:
#    Store  Dept        Date  WeeklySales  HolidayIndicator  year  Month
# 0      1     1    5/2/2010     24924.50             False  2010      5
# 1      1     1   12/2/2010     46039.49              True  2010     12
# 2      1     1  19/02/2010     41595.55             False  2010      2
# 3      1     1  26/02/2010     19403.54             False  2010      2
# 4      1     1    5/3/2010     21827.90             False  2010      5

# %% [markdown]
# ## Show the variation of weekly sales during the month of december of 2010. Make sure you show the weekly sales in millions (Hint: you may need to group by the date and aggregate the sum of weekly sales)

# %%
december_Sales = Sales_df.loc[Sales_df['Month'] == 12]

# %%
december_Sales.head(5)
# Out:
#     Store  Dept        Date  WeeklySales  HolidayIndicator  year  Month
# 1       1     1   12/2/2010     46039.49              True  2010     12
# 5       1     1   12/3/2010     21043.39             False  2010     12
# 40      1     1  12/11/2010     19549.39             False  2010     12
# 45      1     1  17/12/2010     44912.86             False  2010     12
# 46      1     1  24/12/2010     55931.23             False  2010     12

# %% [markdown]
# ## Q4

# %%
plt.plot(december_Sales['Date'],december_Sales['WeeklySales'])

# %% [markdown]
# ## Q5 Comment on the distribution of the size of the store according to the store type( A, B and C) Hint: You may use seaborn library for this task

# %%
Stores_df.head(5)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
ax = sns.boxplot(x = 'Type', y = 'Size', data = Stores_df)

# %%
A is higher distribtuin
